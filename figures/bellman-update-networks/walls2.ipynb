# %%
import wandb
api = wandb.Api()

# %%
# Import seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
group_name = "Sweep n_tasks for tabular/cross-product."
column_key = "train_data_args.sequence_args.grid_world_args.n_tasks"
def access_func(config: dict):
    for key in column_key.split("."):
        config = config[key]
    return config

# %%
import pandas as pd
runs = api.runs("rldl/icvi", {"$and": [{"group": group_name}]})

def generate_dfs():
    for run in runs:
        history = pd.DataFrame(run.history())
        if history['_step'].max() < 300_000:
            continue
        history["seed"] = run.config["seed"]
        history["delta"] = run.config["bellman_delta"]
        history[column_key] = access_func(run.config)
        print(history[column_key])
        yield history

orig = pd.concat(list(generate_dfs()))
orig.columns

# %%
df = orig.rename(columns={"_step": "step", "test-n/rmse": "test", "train-1/rmse": "train"})
df = df[(df["delta"] == 1) | (df["delta"] == 100)]
df["delta"] = df["delta"].replace(100, r"$\delta_{\max}$")
df = df[df["step"] <= 400_000]

df = df.melt(id_vars=['step', "delta", column_key],  # or any other columns you want to keep unchanged
                    value_vars=['test', 'train'],
                    var_name='regime',
                    value_name='root mean-square error')

df =df.rename(columns={"delta": "$\delta$"})
b = 5000
df['step'] = (df['step'] // b) * b
df.columns
# Out:
# /var/folders/mr/d6vzg_f16dn1wl4_2bcx6l9w0000gn/T/ipykernel_40180/3948071748.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["delta"] = df["delta"].replace(100, r"$\delta_{\max}$")
# Index(['step', '$\delta$',
#        'train_data_args.sequence_args.grid_world_args.n_tasks', 'regime',
#        'root mean-square error'],
#       dtype='object')

# %%
import seaborn as sns
sns.reset_defaults()

sns.set(font_scale=2)
sns.set_style('ticks')


g = sns.relplot(data=df, kind="line", x="step", y="root mean-square error", hue="regime", row="$\delta$", col=column_key)
g.set(yscale="log")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /nix/store/rcjn03z3crqzv1h3c7kj95v3gsjwsggi-python3-3.11.6-env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'train_data_args.sequence_args.grid_world_args.n_tasks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 8
#       4 sns.set(font_scale=2)
#       5 sns.set_style('ticks')
# ----> 8 g = sns.relplot(data=df, kind="line", x="step", y="root mean-square error", hue="regime", row="$\delta$", col=column_key)
#       9 g.set(yscale="log")
#      10 plt.show()
#
# File /nix/store/rcjn03z3crqzv1h3c7kj95v3gsjwsggi-python3-3.11.6-env/lib/python3.11/site-packages/seaborn/relational.py:811, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     809 # Set up the FacetGrid object
#     810 facet_kws = {} if facet_kws is None else facet_kws.copy()
# --> 811 g = FacetGrid(
#     812     data=full_data.dropna(axis=1, how="all"),
#     813     **grid_kws,
#     814     col_wrap=col_wrap, row_order=row_order, col_order=col_order,
#     815     height=height, aspect=aspect, dropna=False,
#     816     **facet_kws
#     817 )
#     819 # Draw the plot
#     820 g.map_dataframe(func, **plot_kws)
#
# File /nix/store/rcjn03z3crqzv1h3c7kj95v3gsjwsggi-python3-3.11.6-env/lib/python3.11/site-packages/seaborn/axisgrid.py:402, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     400     col_names = []
#     401 else:
# --> 402     col_names = categorical_order(data[col], col_order)
#     404 # Additional dict of kwarg -> list of values for mapping the hue var
#     405 hue_kws = hue_kws if hue_kws is not None else {}
#
# File /nix/store/rcjn03z3crqzv1h3c7kj95v3gsjwsggi-python3-3.11.6-env/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /nix/store/rcjn03z3crqzv1h3c7kj95v3gsjwsggi-python3-3.11.6-env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'train_data_args.sequence_args.grid_world_args.n_tasks'

# %%
df = orig.rename(columns={"_step": "step", "test-n/regret": "regret"})
df["delta"] = df["delta"].replace(100, r"$\delta_{\max}$")
df = df[df["step"] <= 400_000]
df.loc[:, 'regret'] = df['regret'].clip(lower=1e-6)

window = 10
def calculate_stats(group):
    mean = group['regret'].rolling(window=window).mean()
    std = group['regret'].rolling(window=window).std()
    group['regret'] = mean
    group['upper'] = (mean + std).clip(lower=1e-6)
    group['lower'] = (mean - std).clip(lower=1e-6)
    return group

b = 5000
df.loc[:, 'step'] = (df['step'] // b) * b
df =df.rename(columns={"delta": "$\delta$", "regret": "regret of improved policy"})

# %%
import seaborn as sns

sns.reset_defaults()
sns.set(font_scale=2)
sns.set_style('ticks')

g = sns.relplot(data=df, kind="line", x="step", y="regret of improved policy", hue="$\delta$", col=column_key)
g.set(yscale="log")
plt.show()
